# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv('attacks.csv', encoding = 'latin-1')

# %%
#df.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
#df.describe().T
# Out:
#                  count         mean          std  min     25%     50%     75%  \
# Year            6300.0  1927.272381   281.116308  0.0  1942.0  1977.0  2005.0
# original order  6309.0  3155.999683  1821.396206  2.0  1579.0  3156.0  4733.0
#
#                    max
# Year            2018.0
# original order  6310.0

# %%
df.shape
# Out:
# (25723, 24)

# %%
df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
small_df = df[['Year', 'Type', 'Country', 'Area', 'Location', 'Activity', 'Sex ','Age', 'Fatal (Y/N)', 'Species ']]

# %%
#remove row where all values are None
small_df = small_df.dropna(how='all') 
small_df.head(10)
# Out:
#      Year        Type    Country             Area  \
# 0  2018.0     Boating        USA       California
# 1  2018.0  Unprovoked        USA          Georgia
# 2  2018.0     Invalid        USA           Hawaii
# 3  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.0    Provoked     MEXICO           Colima
# 5  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 6  2018.0  Unprovoked     BRAZIL       Pernambuco
# 7  2018.0  Unprovoked        USA          Florida
# 8  2018.0  Unprovoked        USA          Florida
# 9  2018.0  Unprovoked        USA          Florida
#
#                                             Location      Activity Sex   Age  \
# 0                        Oceanside, San Diego County      Paddling    F   57
# 1                     St. Simon Island, Glynn County      Standing    F   11
# 2                                       Habush, Oahu       Surfing    M   48
# 3                                 Arrawarra Headland       Surfing    M  NaN
# ...

# %%
#para saber el datatype de cada columna
dataTypeSeries = small_df.dtypes
print(dataTypeSeries)
# Out:
# Year           float64
# Type            object
# Country         object
# Area            object
# Location        object
# Activity        object
# Sex             object
# Age             object
# Fatal (Y/N)     object
# Species         object
# dtype: object

# %%
pd.set_option('display.max_rows', None)
#small_df['Species '].value_counts().head(100)

# %%
# cheange NaN to 'Unknown'
small_df['Species '] = small_df['Species '].fillna('No Values')
#rename column
small_df = small_df.rename({'Species ':'Species'}, axis=1)

# %%
small_df.head(20)
# Out:
#       Year          Type       Country                   Area  \
# 0   2018.0       Boating           USA             California
# 1   2018.0    Unprovoked           USA                Georgia
# 2   2018.0       Invalid           USA                 Hawaii
# 3   2018.0    Unprovoked     AUSTRALIA        New South Wales
# 4   2018.0      Provoked        MEXICO                 Colima
# 5   2018.0    Unprovoked     AUSTRALIA        New South Wales
# 6   2018.0    Unprovoked        BRAZIL             Pernambuco
# 7   2018.0    Unprovoked           USA                Florida
# 8   2018.0    Unprovoked           USA                Florida
# 9   2018.0    Unprovoked           USA                Florida
# 10  2018.0      Provoked     AUSTRALIA             Queensland
# 11  2018.0    Unprovoked           USA         South Carolina
# 12  2018.0    Unprovoked           USA         South Carolina
# 13  2018.0       Invalid       ENGLAND               Cornwall
# ...

# %%
Species = ['White Shark','Tiger Shark', 'Bull Shark', 'Blacktip Shark','Blue Shark', 
           'Mako Shark', 'Bronze Whaler Shark', 'Raggedtooth Shark', 'Nurse Shark',
          'Grey Nurse Shark','Zambesi Shark', 'Hammerhead Shark', 'Sandtiger Shark',
          'Basking Shark', 'Lemon Shark', 'Spinner Shark']

pattern = r"[\w]+ shark"

shark_column = []



def change_row_table(string_pattern, *table_columns):
    for line in table_columns[1:]:
        if 'shark' in line or 'Shark' in line:
            if 'involvement' in line:
                shark_column.append('Shark involvement prior to death not confirmed')
            else:
                line = ''.join(re.findall(string_pattern,line)).title()
                if line in Species:
                    shark_column.append(line)
                else: 
                    shark_column.append('Unknown')
        elif line == 'No Values':
            shark_column.append('No Values')
        else: 
            shark_column.append('Unknown')
            
change_row_table(pattern, shark_column, *small_df['Species'])
small_df['Species'] = shark_column

# %%
small_df.head(200)

# %%
small_df.Species.value_counts().head(60)

# %%
small_df.Activity.value_counts().head(30)

# %%
small_df['Activity'] = small_df['Activity'].fillna('No Values')

categories = '''Surfing Swimming Fishing Spearfishing Bathing Wading Diving 
                Standing Snorkeling Kite Scuba Boarding Kayaking Windsurfing'''

activities_column = []



def categorize_row_table(categories, empty_list, *table_columns):
    for line in table_columns:
        line = str(line).title().split()
        for word in line:
            if word.title()[:4] in categories:
                empty_list.append((word.title()[:4]))
                break
        else:
            empty_list.append('Other')


            
categorize_row_table(categories, activities_column, *small_df['Activity'])
small_df['Activity'] = activities_column

# %%
small_df.Activity.value_counts()

# %%
def update_categories_values_table(str_name_column,Dataset,categories):
    for c in categories.split():
        Dataset[f"{str_name_column}"][Dataset[f"{str_name_column}"].str.startswith(f"{c[:4]}")] = f"{c}"
update_categories_values_table('Activity',small_df, categories)

# %%
small_df.head(50)

# %%
small_df.Activity.value_counts().head(15)

# %%
vacia = []
categ = ['Diving','Sailing']
text = ['Diving', 'Dive', 'Pop']
for x in text:
    print(x[:3])
    for a in categ:
        if x[:3] in a:
            vacia.append('Si')
print(vacia)

# %%
print(activities_column)

# %%
small_df.Activity.value_counts()

# %%
#columna species mejorar datos:,[\w]+ shark
Species = ['White shark','Tiger shark', 'Bull shark', 'Blacktip shark','Blue shark', 
           'Mako shark', 'Bronze whaler shark', 'Raggedtooth shark', 'Nurse shark',
          'Grey nurse shark','Zambesi shark', 'Hammerhead shark', 'Sandtiger shark',
          'Basking shark', 'Lemon shark', 'Spinner shark']

def change_row(categories):
    for c in categories:
        for row in small_df['Location']:
            if c in row or c.lower() in row:
                return c
            else:
                return 'Other'
                
[\w]+ shark = list(map(change_row(Species), small_df['Location']))
small_df

# %%
small_df_cols = small_df.isnull().sum().sort_values(ascending=False)
small_df_cols

# %%
small_df['Year'].value_counts().sort_values(ascending=False).head(200)

# %%
null_displ = small_df[(small_df['Fatal (Y/N)'].isnull()==True)]
null_displ = null_displ[['Year', 'Type', 'Country', 'Area', 'Location', 'Activity', 'Sex ','Age', 'Fatal (Y/N)', 'Species ']]
null_displ
# per cambiare valori nelle linee
#data[['displ', 'cylinders']] = data[['displ', 'cylinders']].fillna(0)
#cambiare vlaore nella linea
data.loc[(data['cylinders']==0) & (data['displ']!=0), 'cylinders'] = 4

# %%
print(small_df['Type'].isnull().value_counts())
small_df['Country'].value_counts()

# %%
small_df['Species '].value_counts().head(5)

# %%
def change_row(x):
    if x == 'NaN':
        if x.isdigit() == False:
            return 'Unknown' 

small_df['Species '] = list(map(change_row, small_df['Species ']))

# %%
small_df['Species '].count()

# %%
#Cambiar NAN values
#small_df['Type'] = small_df['Type'].fillna('Unknown')
#small_df['Country'] = small_df['Country'].fillna('Unknown')
#small_df['Area'] = small_df['Area'].fillna('Unknown')
#small_df['Species '] = small_df['Species '].fillna('Unknown')
